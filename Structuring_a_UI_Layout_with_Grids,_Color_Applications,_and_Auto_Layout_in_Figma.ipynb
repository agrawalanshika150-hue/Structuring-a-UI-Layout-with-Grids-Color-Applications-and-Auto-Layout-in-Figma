# %% [markdown]
#  1.set up a grid system in figma to create a structures ui layout
#  - choose a form or dashboard layout for both web and mobile screens
#  - apply consistent spacing, alignment and column structure for a clean design
#  - [Code](https://)https://www.figma.com/design/qRNbJZBvS2X2onglyn7jUY/Untitled?node-id=0-1&t=ESWQGVwi7lB9fTjF-1

# %% [markdown]
# 2. apply color styles and visual aesthetic to maintain consistency
#  - use fill stroke blending modes and opacity to create visual contrast
#  - ensure colors are applied consistently across all ui components
#  - [Code](https://)https://www.figma.com/design/qRNbJZBvS2X2onglyn7jUY/Untitled?node-id=10-10&t=ESWQGVwi7lB9fTjF-1

# %% [markdown]
# 3. define and apply text styles for typography consistency
#  - set text styles for headings labels and buttons
#  - maintain typographic hierarchy to improve readability and usability
#  -[ code](https://)https://www.figma.com/design/qRNbJZBvS2X2onglyn7jUY/Untitled?node-id=10-11&t=ESWQGVwi7lB9fTjF-1

# %% [markdown]
# 4. use auto layout to organize components efficiently
#  - apply constraints to ensure the design adapts responsively across different screen sizes
#  - utilize multi edit text to make quick global adjustments to the design
#  - [code](https://)https://www.figma.com/design/qRNbJZBvS2X2onglyn7jUY/Untitled?node-id=76-23&t=ESWQGVwi7lB9fTjF-1

# %% [markdown]
# 5. submit a structured figma file and a reflection report explaining the applied techniques
# - the figma file should include a properly structured ui layout with grid systems,color application,and auto layout features
# - the report should describe the design process,challenges faced and the impact of autolayout on responsiveness
# - [Code](https://)https://www.figma.com/design/qRNbJZBvS2X2onglyn7jUY/Untitled?node-id=0-1&t=3IozddyTH1A0K7tV-1
# - [Code](https://)https://www.figma.com/design/qRNbJZBvS2X2onglyn7jUY/Untitled?node-id=10-10&t=3IozddyTH1A0K7tV-1
# - [Code](https://)https://www.figma.com/design/qRNbJZBvS2X2onglyn7jUY/Untitled?node-id=10-11&t=3IozddyTH1A0K7tV-1
# - [Code](https://)https://www.figma.com/design/qRNbJZBvS2X2onglyn7jUY/Untitled?node-id=76-23&t=3IozddyTH1A0K7tV-1
# - design process- 1. understanding the layout requirements
# - 2. wireframing and prototyping in figma
# - 3. designing for different viewports
# - 4. implementing flexible components
# - challenges faced- 1. maintaining consistency across screens
# - 2. handling navigation adaptability
# - 3. image and component scaling
# - 4. interactive elements optimization
# - impact of autolayout on responsiveness- it automatically adjusts the arrangement of elements as the content or frame size changes, ensuring consistent and flexible layouts across different devices.
